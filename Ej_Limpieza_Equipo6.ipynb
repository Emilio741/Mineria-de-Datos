# %% [markdown]
# Equipo 6
#
#
# Grupo 002 clase del miercoles
#
#
# 1679700 Salazar Coronado,Sofia
#
#
# 1941534 Chavez Peña,Andres
#
#
# 1852600 Lemus Morales,Ricardo
#
#
# I) Credit Card customers
#
#
# BankChurners
#
#
# https://www.kaggle.com/sakshigoyal7/credit-card-customers
#
#
# #II) Limpieza de datos

# %%
#1) Siguiendo los pasos realizados en la practica uno y dos, iniciar con la limpieza de los datos.
#2) Importar librerias y base de datos.
import pandas as pd
import numpy as np
import json

#3) Insertar los datos y  observarlos sin manipulación.
#Aqui se inserta el csv
baseOG = pd.read_csv("file:///C:/Users/Milol/Desktop/6to%20sem/mineria%20de%20datos/BankChurners.csv")
#Visualizamos datos
baseOG
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
#Con esto vemos que no hay datos nulos
baseOG.isnull()
baseOG.isnull().sum()
#4) Descrpcion básica de columnas (tipo, elementos, celdas vacias, etc.)
# Lo bueno de la base de datos es que no hay columnas vacias, pero si tienen muchos elementos de mas
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
#5)El objetivo es una clasificación con los datos, asi que hay que acomodar los datos de manera que se nos facilite esta tarea.
#b) Eliminar columnas no deseadas.
#c) Correcta manipulación de los datos nulos dentro de la base
base1=baseOG.drop(["CLIENTNUM","Attrition_Flag","Dependent_count","Card_Category","Months_on_book","Total_Relationship_Count","Contacts_Count_12_mon","Total_Revolving_Bal","Avg_Open_To_Buy","Total_Amt_Chng_Q4_Q1","Total_Trans_Amt","Total_Trans_Ct","Total_Ct_Chng_Q4_Q1","Avg_Utilization_Ratio","Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1","Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2"],axis=1)
#d) Explicar a detalle entre cada línea de código la razón por la
#cual se decidió remover o modificar cada columna.
#Guardar otros archivos con agrupaciones.
##CLIENTNUM- no nos importa el numero de cliente
#Attrition_Flag- no nos importa
# Dependent_count- No queremos ver cuantas tarjetas dependen del usuario
#Card_Category no usaremos la categoria de tarjeta
#Months_on_book- El tiempo que lleva registrado no nos importa
#Total_Relationship_Count- NO se usara el total de tarjetas que tiene el usuario
#Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# El indice de no los usaremos, se buscara hacer uno propio Total_Revolving_Bal
#Contacts_Count_12_mon , Total_Revolving_Bal son numeros basados en los contactos de comercio, no se usaran
#"Avg_Open_To_Buy","Total_Amt_Chng_Q4_Q1","Total_Trans_Amt","Total_Trans_Ct","Total_Ct_Chng_Q4_Q1","Avg_Utilization_Ratio
# Los datos de arriba se basan mucho en contexto, a nosotros solo nos importa su entrada de dinero 
#Avg_Utilization_Ratio es un dato muy interesante pero no esta explicado, como no esta claro no se usara
#de datos.
#Cambiar nombres de columnas.
base1= base1.rename(columns = {"Customer_Age":"Edad"})
base1= base1.rename(columns = {"Gender":"Sexo"})
base1= base1.rename(columns = {"Education_Level":"Nivel_Educativo"})
base1= base1.rename(columns = {"Marital_Status":"Estado"})
base1= base1.rename(columns = {"Income_Category":"Sueldo"})
base1= base1.rename(columns = {"Months_Inactive_12_mon":"Meses_Inactivo"})
base1= base1.rename(columns = {"Credit_Limit":"Meses_Inactivo"})
#e) Crear un nuevo archivo con la base de datos editada.
base1

#Responder las preguntas de interes.
# Out:
#        Edad Sexo Nivel_Educativo    Estado          Sueldo  Meses_Inactivo  \
# 0        45    M     High School   Married     $60K - $80K               1
# 1        49    F        Graduate    Single  Less than $40K               1
# 2        51    M        Graduate   Married    $80K - $120K               1
# 3        40    F     High School   Unknown  Less than $40K               4
# 4        40    M      Uneducated   Married     $60K - $80K               1
# ...     ...  ...             ...       ...             ...             ...
# 10122    50    M        Graduate    Single     $40K - $60K               2
# 10123    41    M         Unknown  Divorced     $40K - $60K               2
# 10124    44    F     High School   Married  Less than $40K               3
# 10125    30    M        Graduate   Unknown     $40K - $60K               3
# 10126    43    F        Graduate   Married  Less than $40K               2
#
#        Meses_Inactivo
# 0             12691.0
# ...

# %%
# Pregunta de interes
# La filtracion de nuestros datos no ayuda a tener una base resumida con los datos que nos interesa
# Aparte le cambiamos el nombre de la columna para que sea vea más vistoso y sea más fácil de manejar

# %%
#Referencias
#Eliminar Columnas
#https://www.analyticslane.com/2019/03/25/como-eliminar-columnas-y-filas-en-un-dataframe-pandas/
#Como poner  Markdowns
#https://www.earthdatascience.org/courses/intro-to-earth-data-science/open-reproducible-science/jupyter-python/code-markdown-cells-in-jupyter-notebook/#:~:text=You%20can%20change%20the%20cell%20type%20of%20any%20cell%20in,by%20hitting%20the%20y%20key.
